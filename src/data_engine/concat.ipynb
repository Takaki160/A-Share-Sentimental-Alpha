# %%
import pandas as pd

# %%
df_2021_2022 = pd.read_csv('C:/Users/User/Documents/A-Share-Sentimental-Alpha/data/master_alignment_table_2021_2022.csv')
df_2023_2024 = pd.read_csv('C:/Users/User/Documents/A-Share-Sentimental-Alpha/data/master_alignment_table_2023_2024.csv')

# %%
df = pd.concat([df_2021_2022, df_2023_2024], ignore_index=True)
df.to_csv('C:/Users/User/Documents/A-Share-Sentimental-Alpha/data/master_alignment_table.csv', index=False)
